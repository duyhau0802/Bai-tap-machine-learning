# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Input, Flatten, Dropout
from tensorflow.keras.layers import concatenate, Activation
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import os
import numpy as np
import math

# training parameters
batch_size = 32
epochs = 100
data_augmentation = True

# network parameters
num_classes = 10
num_dense_blocks = 3
use_max_pool = False

# DenseNet-BC with dataset augmentation
# Growth rate   | Depth |  Accuracy (paper)| Accuracy (this)      |
# 12            | 100   |  95.49%          | 93.74%               |
# 24            | 250   |  96.38%          | requires big mem GPU |
# 40            | 190   |  96.54%          | requires big mem GPU |
growth_rate = 12
depth = 100
num_bottleneck_layers = (depth - 4) // (2 * num_dense_blocks)

num_filters_bef_dense_block = 2 * growth_rate
compression_factor = 0.5

# load the CIFAR10 data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# input image dimensions
input_shape = x_train.shape[1:]

# mormalize data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


# start model definition
# densenet CNNs (composite function) are made of BN-ReLU-Conv2D
inputs = Input(shape=input_shape)
x = BatchNormalization()(inputs)
x = Activation('relu')(x)
x = Conv2D(num_filters_bef_dense_block,
           kernel_size=3,
           padding='same',
           kernel_initializer='he_normal')(x)
x = concatenate([inputs, x])

# stack of dense blocks bridged by transition layers
for i in range(num_dense_blocks):
    # a dense block is a stack of bottleneck layers
    for j in range(num_bottleneck_layers):
        y = BatchNormalization()(x)
        y = Activation('relu')(y)
        y = Conv2D(4 * growth_rate,
                   kernel_size=1,
                   padding='same',
                   kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(growth_rate,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        x = concatenate([x, y])

    # no transition layer after the last dense block
    if i == num_dense_blocks - 1:
        continue

    # transition layer compresses num of feature maps and reduces the size by 2
    num_filters_bef_dense_block += num_bottleneck_layers * growth_rate
    num_filters_bef_dense_block = int(num_filters_bef_dense_block * compression_factor)
    y = BatchNormalization()(x)
    y = Conv2D(num_filters_bef_dense_block,
               kernel_size=1,
               padding='same',
               kernel_initializer='he_normal')(y)
    if not data_augmentation:
        y = Dropout(0.2)(y)
    x = AveragePooling2D()(y)


# add classifier on top
# after average pooling, size of feature map is 1 x 1
x = AveragePooling2D(pool_size=8)(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                kernel_initializer='he_normal',
                activation='softmax')(y)

# instantiate and compile model
# orig paper uses SGD but RMSprop works better for DenseNet
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(1e-3),
              metrics=['acc'])
model.summary()
# enable this if pydot can be installed
# pip install pydot
#plot_model(model, to_file="cifar10-densenet.png", show_shapes=True)

# prepare model model saving directory
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_densenet_model.{epoch:02d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate reducer
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # preprocessing  and realtime data augmentation
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (deg 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally
        height_shift_range=0.1,  # randomly shift images vertically
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(x_train)

    steps_per_epoch = math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  batch_normalization_1 (Bat  (None, 32, 32, 3)            12        ['input_2[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 32, 32, 3)            0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d (Conv2D)             (None, 32, 32, 24)           672       ['activation[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 32, 27)           0         ['input_2[0][0]',
#                                                                      'conv2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 27)           108       ['concatenate[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 27)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 48)           1344      ['activation_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 48)           192       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 32, 32, 39)           0         ['concatenate[0][0]',
#  )                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 39)           156       ['concatenate_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 39)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 48)           1920      ['activation_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 48)           192       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 51)           0         ['concatenate_1[0][0]',
#  )                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 51)           204       ['concatenate_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 51)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 48)           2496      ['activation_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 48)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 63)           0         ['concatenate_2[0][0]',
#  )                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 63)           252       ['concatenate_3[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 63)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 48)           3072      ['activation_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 48)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 48)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 12)           5196      ['activation_8[0][0]']
#
#  concatenate_4 (Concatenate  (None, 32, 32, 75)           0         ['concatenate_3[0][0]',
#  )                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 32, 32, 75)           300       ['concatenate_4[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 75)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 48)           3648      ['activation_9[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 48)           192       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_10[0][0]']
#
#  concatenate_5 (Concatenate  (None, 32, 32, 87)           0         ['concatenate_4[0][0]',
#  )                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 32, 32, 87)           348       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 87)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 48)           4224      ['activation_11[0][0]']
#
#  batch_normalization_13 (Ba  (None, 32, 32, 48)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_12[0][0]']
#
#  concatenate_6 (Concatenate  (None, 32, 32, 99)           0         ['concatenate_5[0][0]',
#  )                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 99)           396       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 32, 32, 99)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 48)           4800      ['activation_13[0][0]']
#
#  batch_normalization_15 (Ba  (None, 32, 32, 48)           192       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_14[0][0]']
#
#  concatenate_7 (Concatenate  (None, 32, 32, 111)          0         ['concatenate_6[0][0]',
#  )                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 111)          444       ['concatenate_7[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 111)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 48)           5376      ['activation_15[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 48)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_16[0][0]']
#
#  concatenate_8 (Concatenate  (None, 32, 32, 123)          0         ['concatenate_7[0][0]',
#  )                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_18 (Ba  (None, 32, 32, 123)          492       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 32, 32, 123)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 48)           5952      ['activation_17[0][0]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 48)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_18[0][0]']
#
#  concatenate_9 (Concatenate  (None, 32, 32, 135)          0         ['concatenate_8[0][0]',
#  )                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 135)          540       ['concatenate_9[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 32, 32, 135)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 48)           6528      ['activation_19[0][0]']
#
#  batch_normalization_21 (Ba  (None, 32, 32, 48)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_20[0][0]']
#
#  concatenate_10 (Concatenat  (None, 32, 32, 147)          0         ['concatenate_9[0][0]',
#  e)                                                                  'conv2d_20[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 32, 147)          588       ['concatenate_10[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 32, 32, 147)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 48)           7104      ['activation_21[0][0]']
#
#  batch_normalization_23 (Ba  (None, 32, 32, 48)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_22[0][0]']
#
#  concatenate_11 (Concatenat  (None, 32, 32, 159)          0         ['concatenate_10[0][0]',
#  e)                                                                  'conv2d_22[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 32, 159)          636       ['concatenate_11[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 32, 32, 159)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 48)           7680      ['activation_23[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 48)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_24[0][0]']
#
#  concatenate_12 (Concatenat  (None, 32, 32, 171)          0         ['concatenate_11[0][0]',
#  e)                                                                  'conv2d_24[0][0]']
#
#  batch_normalization_26 (Ba  (None, 32, 32, 171)          684       ['concatenate_12[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32, 32, 171)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 48)           8256      ['activation_25[0][0]']
#
#  batch_normalization_27 (Ba  (None, 32, 32, 48)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_26[0][0]']
#
#  concatenate_13 (Concatenat  (None, 32, 32, 183)          0         ['concatenate_12[0][0]',
#  e)                                                                  'conv2d_26[0][0]']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 183)          732       ['concatenate_13[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 32, 32, 183)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 48)           8832      ['activation_27[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 48)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_28[0][0]']
#
#  concatenate_14 (Concatenat  (None, 32, 32, 195)          0         ['concatenate_13[0][0]',
#  e)                                                                  'conv2d_28[0][0]']
#
#  batch_normalization_30 (Ba  (None, 32, 32, 195)          780       ['concatenate_14[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 32, 32, 195)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 48)           9408      ['activation_29[0][0]']
#
#  batch_normalization_31 (Ba  (None, 32, 32, 48)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_30[0][0]']
#
#  concatenate_15 (Concatenat  (None, 32, 32, 207)          0         ['concatenate_14[0][0]',
#  e)                                                                  'conv2d_30[0][0]']
#
#  batch_normalization_32 (Ba  (None, 32, 32, 207)          828       ['concatenate_15[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 32, 32, 207)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 48)           9984      ['activation_31[0][0]']
#
#  batch_normalization_33 (Ba  (None, 32, 32, 48)           192       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 48)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 12)           5196      ['activation_32[0][0]']
#
#  concatenate_16 (Concatenat  (None, 32, 32, 219)          0         ['concatenate_15[0][0]',
#  e)                                                                  'conv2d_32[0][0]']
#
#  batch_normalization_34 (Ba  (None, 32, 32, 219)          876       ['concatenate_16[0][0]']
#  tchNormalization)
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 108)          23760     ['batch_normalization_34[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 16, 16, 108)          0         ['conv2d_33[0][0]']
#  Pooling2D)
#
#  batch_normalization_35 (Ba  (None, 16, 16, 108)          432       ['average_pooling2d[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 16, 16, 108)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 48)           5232      ['activation_33[0][0]']
#
#  batch_normalization_36 (Ba  (None, 16, 16, 48)           192       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_34[0][0]']
#
#  concatenate_17 (Concatenat  (None, 16, 16, 120)          0         ['average_pooling2d[0][0]',
#  e)                                                                  'conv2d_35[0][0]']
#
#  batch_normalization_37 (Ba  (None, 16, 16, 120)          480       ['concatenate_17[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 16, 16, 120)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 48)           5808      ['activation_35[0][0]']
#
#  batch_normalization_38 (Ba  (None, 16, 16, 48)           192       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_36[0][0]']
#
#  concatenate_18 (Concatenat  (None, 16, 16, 132)          0         ['concatenate_17[0][0]',
#  e)                                                                  'conv2d_37[0][0]']
#
#  batch_normalization_39 (Ba  (None, 16, 16, 132)          528       ['concatenate_18[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 16, 16, 132)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 48)           6384      ['activation_37[0][0]']
#
#  batch_normalization_40 (Ba  (None, 16, 16, 48)           192       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_38[0][0]']
#
#  concatenate_19 (Concatenat  (None, 16, 16, 144)          0         ['concatenate_18[0][0]',
#  e)                                                                  'conv2d_39[0][0]']
#
#  batch_normalization_41 (Ba  (None, 16, 16, 144)          576       ['concatenate_19[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 16, 16, 144)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 48)           6960      ['activation_39[0][0]']
#
#  batch_normalization_42 (Ba  (None, 16, 16, 48)           192       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_40[0][0]']
#
#  concatenate_20 (Concatenat  (None, 16, 16, 156)          0         ['concatenate_19[0][0]',
#  e)                                                                  'conv2d_41[0][0]']
#
#  batch_normalization_43 (Ba  (None, 16, 16, 156)          624       ['concatenate_20[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 16, 16, 156)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 16, 16, 48)           7536      ['activation_41[0][0]']
#
#  batch_normalization_44 (Ba  (None, 16, 16, 48)           192       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_42[0][0]']
#
#  concatenate_21 (Concatenat  (None, 16, 16, 168)          0         ['concatenate_20[0][0]',
#  e)                                                                  'conv2d_43[0][0]']
#
#  batch_normalization_45 (Ba  (None, 16, 16, 168)          672       ['concatenate_21[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 16, 16, 168)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 16, 16, 48)           8112      ['activation_43[0][0]']
#
#  batch_normalization_46 (Ba  (None, 16, 16, 48)           192       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_44[0][0]']
#
#  concatenate_22 (Concatenat  (None, 16, 16, 180)          0         ['concatenate_21[0][0]',
#  e)                                                                  'conv2d_45[0][0]']
#
#  batch_normalization_47 (Ba  (None, 16, 16, 180)          720       ['concatenate_22[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 16, 16, 180)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 16, 16, 48)           8688      ['activation_45[0][0]']
#
#  batch_normalization_48 (Ba  (None, 16, 16, 48)           192       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_46[0][0]']
#
#  concatenate_23 (Concatenat  (None, 16, 16, 192)          0         ['concatenate_22[0][0]',
#  e)                                                                  'conv2d_47[0][0]']
#
#  batch_normalization_49 (Ba  (None, 16, 16, 192)          768       ['concatenate_23[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 16, 16, 192)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 48)           9264      ['activation_47[0][0]']
#
#  batch_normalization_50 (Ba  (None, 16, 16, 48)           192       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 16, 16, 48)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 12)           5196      ['activation_48[0][0]']
#
#  concatenate_24 (Concatenat  (None, 16, 16, 204)          0         ['concatenate_23[0][0]',
#  e)                                                                  'conv2d_49[0][0]']
#
#  batch_normalization_51 (Ba  (None, 16, 16, 204)          816       ['concatenate_24[0][0]']
#  tchNormalization)
# ...
#  tchNormalization)
#
#  activation_81 (Activation)  (None, 8, 8, 246)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 8, 8, 48)             11856     ['activation_81[0][0]']
#
#  batch_normalization_85 (Ba  (None, 8, 8, 48)             192       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_84 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_82[0][0]']
#
#  concatenate_41 (Concatenat  (None, 8, 8, 258)            0         ['concatenate_40[0][0]',
#  e)                                                                  'conv2d_84[0][0]']
#
#  batch_normalization_86 (Ba  (None, 8, 8, 258)            1032      ['concatenate_41[0][0]']
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 8, 8, 258)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 8, 8, 48)             12432     ['activation_83[0][0]']
#
#  batch_normalization_87 (Ba  (None, 8, 8, 48)             192       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_84 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_84[0][0]']
#
#  concatenate_42 (Concatenat  (None, 8, 8, 270)            0         ['concatenate_41[0][0]',
#  e)                                                                  'conv2d_86[0][0]']
#
#  batch_normalization_88 (Ba  (None, 8, 8, 270)            1080      ['concatenate_42[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 8, 8, 270)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 8, 8, 48)             13008     ['activation_85[0][0]']
#
#  batch_normalization_89 (Ba  (None, 8, 8, 48)             192       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_86[0][0]']
#
#  concatenate_43 (Concatenat  (None, 8, 8, 282)            0         ['concatenate_42[0][0]',
#  e)                                                                  'conv2d_88[0][0]']
#
#  batch_normalization_90 (Ba  (None, 8, 8, 282)            1128      ['concatenate_43[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 8, 8, 282)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 8, 8, 48)             13584     ['activation_87[0][0]']
#
#  batch_normalization_91 (Ba  (None, 8, 8, 48)             192       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_88 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  conv2d_90 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_88[0][0]']
#
#  concatenate_44 (Concatenat  (None, 8, 8, 294)            0         ['concatenate_43[0][0]',
#  e)                                                                  'conv2d_90[0][0]']
#
#  batch_normalization_92 (Ba  (None, 8, 8, 294)            1176      ['concatenate_44[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 8, 8, 294)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_91 (Conv2D)          (None, 8, 8, 48)             14160     ['activation_89[0][0]']
#
#  batch_normalization_93 (Ba  (None, 8, 8, 48)             192       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  activation_90 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  conv2d_92 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_90[0][0]']
#
#  concatenate_45 (Concatenat  (None, 8, 8, 306)            0         ['concatenate_44[0][0]',
#  e)                                                                  'conv2d_92[0][0]']
#
#  batch_normalization_94 (Ba  (None, 8, 8, 306)            1224      ['concatenate_45[0][0]']
#  tchNormalization)
#
#  activation_91 (Activation)  (None, 8, 8, 306)            0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_93 (Conv2D)          (None, 8, 8, 48)             14736     ['activation_91[0][0]']
#
#  batch_normalization_95 (Ba  (None, 8, 8, 48)             192       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_92 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_92[0][0]']
#
#  concatenate_46 (Concatenat  (None, 8, 8, 318)            0         ['concatenate_45[0][0]',
#  e)                                                                  'conv2d_94[0][0]']
#
#  batch_normalization_96 (Ba  (None, 8, 8, 318)            1272      ['concatenate_46[0][0]']
#  tchNormalization)
#
#  activation_93 (Activation)  (None, 8, 8, 318)            0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 8, 8, 48)             15312     ['activation_93[0][0]']
#
#  batch_normalization_97 (Ba  (None, 8, 8, 48)             192       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_94[0][0]']
#
#  concatenate_47 (Concatenat  (None, 8, 8, 330)            0         ['concatenate_46[0][0]',
#  e)                                                                  'conv2d_96[0][0]']
#
#  batch_normalization_98 (Ba  (None, 8, 8, 330)            1320      ['concatenate_47[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 8, 8, 330)            0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 48)             15888     ['activation_95[0][0]']
#
#  batch_normalization_99 (Ba  (None, 8, 8, 48)             192       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 8, 8, 48)             0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 8, 8, 12)             5196      ['activation_96[0][0]']
#
#  concatenate_48 (Concatenat  (None, 8, 8, 342)            0         ['concatenate_47[0][0]',
#  e)                                                                  'conv2d_98[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 342)            0         ['concatenate_48[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 342)                  0         ['average_pooling2d_2[0][0]']
#
#  dense (Dense)               (None, 10)                   3430      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 797788 (3.04 MB)
# Trainable params: 774376 (2.95 MB)
# Non-trainable params: 23412 (91.45 KB)
# __________________________________________________________________________________________________
# Using real-time data augmentation.

# %%
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)


    # fit the model on the batches generated by datagen.flow()
    #model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    ##                    steps_per_epoch=x_train.shape[0] // batch_size,
    #                    validation_data=(x_test, y_test),
    #                    epochs=epochs, verbose=1,
    #                    callbacks=callbacks)

# score trained model
# Out:
# Learning rate:  0.001
# Epoch 1/100
# 782/782 [==============================] - ETA: 0s - loss: 0.1647 - acc: 0.9412
# Epoch 1: val_acc did not improve from 0.87820
# 782/782 [==============================] - 142s 181ms/step - loss: 0.1647 - acc: 0.9412 - val_loss: 0.4794 - val_acc: 0.8695 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 549/782 [====================>.........] - ETA: 40s - loss: 0.1554 - acc: 0.9469
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1c92ab49f88a> in <cell line: 1>()
# ----> 1 model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
#       2           verbose=1,
#       3           epochs=epochs,
#       4           validation_data=(x_test, y_test),
#       5           steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1746                             logs = tmp_logs
#    1747                             end_step = step + data_handler.step_increment
# -> 1748                             callbacks.on_train_batch_end(end_step, logs)
#    1749                             if self.stop_training:
#    1750                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     692         return t.item() if np.ndim(t) == 0 else t
#     693
# --> 694     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     695
#     696
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     622     ValueError: If wrong keyword arguments are provided.
#     623   """
# --> 624   return nest_util.map_structure(
#     625       nest_util.Modality.CORE, func, *structure, **kwargs
#     626   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1052   """
#    1053   if modality == Modality.CORE:
# -> 1054     return _tf_core_map_structure(func, *structure, **kwargs)
#    1055   elif modality == Modality.DATA:
#    1056     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1092   return _tf_core_pack_sequence_as(
#    1093       structure[0],
# -> 1094       [func(*x) for x in entries],
#    1095       expand_composites=expand_composites,
#    1096   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1092   return _tf_core_pack_sequence_as(
#    1093       structure[0],
# -> 1094       [func(*x) for x in entries],
#    1095       expand_composites=expand_composites,
#    1096   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     685         # Don't turn ragged or sparse tensors to NumPy.
#     686         if isinstance(t, tf.Tensor):
# --> 687             t = t.numpy()
#     688         # Strings, ragged and sparse tensors don't have .item(). Return them
#     689         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1139     """
#    1140     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1141     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1142     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1143
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1105   def _numpy(self):
#    1106     try:
# -> 1107       return self._numpy_internal()
#    1108     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1109       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
import tensorflow as tf

batch_size = 64
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)

train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size

# %%
from time import time

t1 = time()
r = model.fit(train_generator, validation_data=(x_test, y_test),
			steps_per_epoch=steps_per_epoch, epochs=50)

t2 = time()
# Out:
# Epoch 1/50
# 781/781 [==============================] - 144s 184ms/step - loss: 0.1537 - acc: 0.9465 - val_loss: 0.4797 - val_acc: 0.8643
# Epoch 2/50
# 781/781 [==============================] - 141s 181ms/step - loss: 0.1489 - acc: 0.9476 - val_loss: 0.5571 - val_acc: 0.8620
# Epoch 3/50
# 781/781 [==============================] - 141s 181ms/step - loss: 0.1439 - acc: 0.9497 - val_loss: 0.4482 - val_acc: 0.8785
# Epoch 4/50
# 119/781 [===>..........................] - ETA: 1:56 - loss: 0.1265 - acc: 0.9548
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ea8094ee20d5> in <cell line: 4>()
#       2
#       3 t1 = time()
# ----> 4 r = model.fit(train_generator, validation_data=(x_test, y_test),
#       5 			steps_per_epoch=steps_per_epoch, epochs=50)
#       6
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1740                         ):
#    1741                             callbacks.on_train_batch_begin(step)
# -> 1742                             tmp_logs = self.train_function(iterator)
#    1743                             if data_handler.should_sync:
#    1744                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     823
#     824       with OptionalXlaContext(self._jit_compile):
# --> 825         result = self._call(*args, **kwds)
#     826
#     827       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     855       # In this case we have created variables on the first call, so we run the
#     856       # defunned version which is guaranteed to never create variables.
# --> 857       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858     elif self._variable_creation_fn is not None:
#     859       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     146       (concrete_function,
#     147        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148     return concrete_function._call_flat(
#     149         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     150
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs)
#    1347         and executing_eagerly):
#    1348       # No tape is watching; skip to running the function.
# -> 1349       return self._build_call_outputs(self._inference_function(*args))
#    1350     forward_backward = self._select_forward_and_backward_functions(
#    1351         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     194         with record.stop_recording():
#     195           if self._bound_context.executing_eagerly():
# --> 196             outputs = self._bound_context.call_function(
#     197                 self.name,
#     198                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1455     cancellation_context = cancellation.context()
#    1456     if cancellation_context is None:
# -> 1457       outputs = execute.execute(
#    1458           name.decode("utf-8"),
#    1459           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save("model_densenet02.h1")
import zipfile, os
folder_path = 'model_densenet02.h1'
zip_file_name = 'model_densenet02.h1.zip'

def zip_folder(folder_path, zip_file_name):
    zip_file = zipfile.ZipFile(zip_file_name, 'w')

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            zip_file.write(os.path.join(root, file))

    zip_file.close()
zip_folder(folder_path, zip_file_name)

# %%
scores = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 0.5957868695259094
# Test accuracy: 0.8575999736785889
